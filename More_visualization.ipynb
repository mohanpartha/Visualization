# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# # Ploting the composition of data

# %% [markdown]
# ## Static Composition

# %% [markdown]
# ## Pie Chart

# %%
p = sns.load_dataset('penguins')

# %%
p.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
p.groupby('species').count()
# Out:
#            island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# species
# Adelie        152               151              151                151
# Chinstrap      68                68               68                 68
# Gentoo        124               123              123                123
#
#            body_mass_g  sex
# species
# Adelie             151  146
# Chinstrap           68   68
# Gentoo             123  119

# %%
p.groupby('species')['species'].count()
# Out:
# species
# Adelie       152
# Chinstrap     68
# Gentoo       124
# Name: species, dtype: int64

# %%
c = p.groupby('species')['species'].count()

# %%
plt.pie(c);

# %%
plt.pie(c)
plt.show()

# %%
plt.pie(c,labels=c.index)
plt.show()

# %%
plt.pie(c,labels=c.index,autopct='%.2f%%');
plt.show()

# %%
plt.pie(c,labels=c.index,autopct='%.2f%%',explode=[0,1,0]);
plt.show()

# %%
plt.pie(c,labels=c.index,autopct='%.2f%%',explode=[0,1,0],startangle=180);
plt.show()

# %%
plt.pie(c,labels=c.index,autopct='%.2f%%',explode=[0,1,0],
        startangle=180,shadow=True);
plt.show()

# %%
plt.pie(np.random.randint(0,10,10));
plt.show()

# %% [markdown]
# ## Donut Chart

# %%
plt.pie(np.random.randint(0,10,10),wedgeprops=dict(width=0.3));
plt.show()

# %%
cmap=plt.get_cmap('Accent')
my_color = cmap(np.arange(10))

# %%
plt.pie(c,labels=c.index, wedgeprops=dict(width=0.3), autopct="%.2f%%",
        colors=my_color);
plt.show()

# %%
c_i = p.groupby('island')['island'].count()

# %%
c_i
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
plt.pie(c_i,labels=c_i.index, wedgeprops=dict(width=0.3), autopct="%.2f%%",
        colors=my_color);
plt.show()

# %%
c1 = pd.crosstab(p.island,p.species)

# %%
c1
# Out:
# species    Adelie  Chinstrap  Gentoo
# island
# Biscoe         44          0     124
# Dream          56         68       0
# Torgersen      52          0       0

# %%
c1 = c1.T

# %%
c1
# Out:
# island     Biscoe  Dream  Torgersen
# species
# Adelie         44     56         52
# Chinstrap       0     68          0
# Gentoo        124      0          0

# %%
plt.pie(c1.sum(axis=1),labels=c1.index, wedgeprops=dict(width=0.3),
        colors=my_color, radius=1);
plt.show()

# %%
plt.pie(c1.sum(axis=1),labels=c1.index, wedgeprops=dict(width=0.3),
        colors=my_color, radius=1);
plt.pie(c1.values.flatten(),radius= 0.7);

# %%
cmap = plt.get_cmap('tab20c')
outer_color = cmap(np.array([0, 4, 8]))
inner_color = cmap(np.array([1, 2, 3, 5, 6, 7, 9, 10, 11]))

# %%
plt.pie(c1.sum(axis=1),labels=c1.index, wedgeprops=dict(width=0.3),
        colors=outer_color, radius=1);
plt.pie(c1.values.flatten(),radius= 0.7,
        labels=['A','C','G','A','C','G','A','C','G'],
        colors=inner_color);

# %%
plt.pie(c1.sum(axis=1),labels=c1.index, wedgeprops=dict(width=0.3),
        colors=outer_color, radius=1);
plt.pie(c1.values.flatten(),radius= 0.7,
        labels=['A','','G','A','C','','A','',''],
        colors=inner_color);

# %%
plt.pie(c1.sum(axis=1),labels=c1.index, wedgeprops=dict(width=0.3),
        colors=outer_color, radius=1);
plt.pie(c1.values.flatten(),radius= 0.7,
        labels=['A','','G','A','C','','A','',''], labeldistance= 0.75,
        colors=inner_color);

# %%
cmap = plt.get_cmap('tab20b')
outer_color = cmap(np.array([0, 4, 8]))
inner_color = cmap(np.array([1, 2, 3, 5, 6, 7, 9, 10, 11]))

# %%
plt.pie(c1.sum(axis=1),labels=c1.index, wedgeprops=dict(width=0.3),
        colors=outer_color, radius=1);
plt.pie(c1.values.flatten(),radius= 0.7,
        labels=['A','','G','A','C','','A','',''], labeldistance= 0.75,
        colors=inner_color);

# %%
plt.pie(c1.sum(axis=1),labels=c1.index, wedgeprops=dict(width=0.3),
        colors=outer_color, radius=1);
plt.pie(c1.values.flatten(),radius= 0.7,
        labels=['A','','G','A','C','','A','',''], labeldistance= 0.75,
        colors=inner_color, textprops=dict(color='w'));

# %%
import pandas as pd
import urllib.request
import json

# %%
url = 'https://api.covid19india.org/states_daily.json'
urllib.request.urlretrieve(url,'data.json')
with open('data.json') as f:
  data = json.load(f)
data = data['states_daily']
df = pd.json_normalize(data)

# %%
df_ = df.tail(3)
df_.drop('date', axis=1, inplace = True)
df_.set_index('status',inplace=True)
df_ = df_.T
df_ = df_.apply(pd.to_numeric)
df_.drop('tt', inplace = True)
# Out:
# /Users/partha/.local/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_.head()
# Out:
# status  Confirmed  Recovered  Deceased
# an              0          0         0
# ap           3963       1465        52
# ar             41         99         0
# as              0       1060         2
# br           1667        774         4

# %%
plt.bar(df_.index,df_['Confirmed']);
plt.xticks(rotation=90);

# %%
plt.bar(df_.index,df_['Confirmed']);
plt.bar(df_.index,df_['Recovered'],bottom = df_.Confirmed);
plt.xticks(rotation=90);

# %%
plt.bar(df_.index,df_['Confirmed']);
plt.bar(df_.index,df_['Recovered'],bottom = df_.Confirmed);
plt.bar(df_.index,df_['Deceased'],bottom = df_.Confirmed + df_.Recovered);
plt.xticks(rotation=90);

# %%
fig = plt.gcf()
fig.set_size_inches(10,6)

plt.bar(df_.index,df_['Confirmed']);
plt.bar(df_.index,df_['Recovered'],bottom = df_.Confirmed);
plt.bar(df_.index,df_['Deceased'],bottom = df_.Confirmed + df_.Recovered);
plt.xticks(rotation=90);

# %%
fig = plt.gcf()
fig.set_size_inches(15,6)

plt.bar(df_.index,df_['Confirmed'], color = 'orange');
plt.bar(df_.index,df_['Recovered'],bottom = df_.Confirmed, color='green');
plt.bar(df_.index,df_['Deceased'],bottom = df_.Confirmed + df_.Recovered,color='red');
plt.xticks(rotation=90);

# %%
fig = plt.gcf()
fig.set_size_inches(15,6)

plt.bar(df_.index,df_['Confirmed'], color = 'orange');
plt.bar(df_.index,df_['Recovered'],bottom = df_.Confirmed, color='green');
plt.bar(df_.index,df_['Deceased'],bottom = df_.Confirmed + df_.Recovered,color='red');
plt.xticks(rotation=90);

for i, val in enumerate(df_.index):
    y = df_.loc[val].sum()
    if y > 1000:
        x = i
        plt.text(x, y, str(y), ha='center')

# %% [markdown]
# ### Relative Stacked Bar Chart ###

# %%
df_['Total'] = 0

# %%
df_['Total'] = df_.sum(axis=1)

# %%
df_.head()
# Out:
# status  Confirmed  Recovered  Deceased  Total
# an              0          0         0      0
# ap           3963       1465        52   5480
# ar             41         99         0    140
# as              0       1060         2   1062
# br           1667        774         4   2445

# %%
df_['Confirmedfraction'] = df_['Confirmed'] / df_['Total']
df_['Recoveredfraction'] = df_['Recovered'] / df_['Total']
df_['Deceasedfraction'] = df_['Deceased'] / df_['Total']

# %%
df_
# Out:
# status  Confirmed  Recovered  Deceased  Total  Confirmedfraction  \
# an              0          0         0      0                NaN
# ap           3963       1465        52   5480           0.723175
# ar             41         99         0    140           0.292857
# as              0       1060         2   1062           0.000000
# br           1667        774         4   2445           0.681800
# ch             31          5         1     37           0.837838
# ct            243        146         0    389           0.624679
# dd              0          0         0      0                NaN
# dl           1475       1973        26   3474           0.424583
# dn             45         22         0     67           0.671642
# ga            180         92         0    272           0.661765
# gj            960       1061        19   2040           0.470588
# hp             40         19         0     59           0.677966
# hr            750        600        17   1367           0.548647
# jh            289         79         2    370           0.781081
# jk            441        607         5   1053           0.418803
# ka           4537       1018        93   5648           0.803293
# kl            593        204         2    799           0.742178
# la              8         12         0     20           0.400000
# ld              0          0         0      0                NaN
# mh           8348       5306       144  13798           0.605015
# ml             15          0         0     15           1.000000
# mn             91         19         0    110           0.827273
# mp            681        350         8   1039           0.655438
# mz              2          7         0      9           0.222222
# nl             22          0         0     22           1.000000
# or            591        607         3   1201           0.492090
# pb            350         81         7    438           0.799087
# py             58         48         3    109           0.532110
# rj            711        518         7   1236           0.575243
# sk             19          2         0     21           0.904762
# tg            617       1902         6   2525           0.244356
# tn           4807       3049        88   7944           0.605111
# tr            171          0         2    173           0.988439
# un           -368          0         0   -368           1.000000
# up           1873       1030        24   2927           0.639904
# ut            174         60         1    235           0.740426
# wb           2198       1286        27   3511           0.626032
#
# status  Recoveredfraction  Deceasedfraction
# an                    NaN               NaN
# ap               0.267336          0.009489
# ar               0.707143          0.000000
# as               0.998117          0.001883
# br               0.316564          0.001636
# ch               0.135135          0.027027
# ct               0.375321          0.000000
# dd                    NaN               NaN
# dl               0.567933          0.007484
# dn               0.328358          0.000000
# ga               0.338235          0.000000
# gj               0.520098          0.009314
# hp               0.322034          0.000000
# hr               0.438917          0.012436
# jh               0.213514          0.005405
# jk               0.576448          0.004748
# ka               0.180241          0.016466
# kl               0.255319          0.002503
# la               0.600000          0.000000
# ld                    NaN               NaN
# mh               0.384548          0.010436
# ml               0.000000          0.000000
# mn               0.172727          0.000000
# mp               0.336862          0.007700
# mz               0.777778          0.000000
# nl               0.000000          0.000000
# or               0.505412          0.002498
# pb               0.184932          0.015982
# py               0.440367          0.027523
# rj               0.419094          0.005663
# sk               0.095238          0.000000
# tg               0.753267          0.002376
# tn               0.383812          0.011078
# tr               0.000000          0.011561
# un              -0.000000         -0.000000
# up               0.351896          0.008200
# ut               0.255319          0.004255
# wb               0.366277          0.007690

# %%
fig = plt.gcf()
fig.set_size_inches(15,6)

plt.bar(df_.index,df_['Confirmedfraction'], color = 'orange');
plt.bar(df_.index,df_['Recoveredfraction'],bottom = df_.Confirmedfraction, color='green');
plt.bar(df_.index,df_['Deceasedfraction'],bottom = df_.Confirmedfraction + df_.Recoveredfraction,color='red');
plt.xticks(rotation=90);

# %%
df_ = df_.sort_values('Confirmedfraction', ascending=False)

# %%
fig = plt.gcf()
fig.set_size_inches(15,6)

plt.bar(df_.index,df_['Confirmedfraction'], color = 'orange');
plt.bar(df_.index,df_['Recoveredfraction'],bottom = df_.Confirmedfraction, color='green');
plt.bar(df_.index,df_['Deceasedfraction'],bottom = df_.Confirmedfraction + df_.Recoveredfraction,color='red');
plt.xticks(rotation=90);

# %%
df_ = df_.sort_values('Total', ascending=False)
fig = plt.gcf()
fig.set_size_inches(15,6)

plt.bar(df_.index,df_['Confirmed'], color = 'orange');
plt.bar(df_.index,df_['Recovered'],bottom = df_.Confirmed, color='green');
plt.bar(df_.index,df_['Deceased'],bottom = df_.Confirmed + df_.Recovered,color='red');
plt.xticks(rotation=90);

for i, val in enumerate(df_.index):
    y = df_.loc[val, 'Total'] +100
    if y > 1000:
        x = i
        plt.text(x, y, str(y), ha='center')

# %%
df_ = df_.sort_values('Total', ascending=False)
fig = plt.gcf()
fig.set_size_inches(15,6)

plt.barh(df_.index,df_['Confirmed'], color = 'orange');
plt.barh(df_.index,df_['Recovered'], left= df_.Confirmed, color='green');
plt.barh(df_.index,df_['Deceased'], left= df_.Confirmed + df_.Recovered,color='red');
plt.xticks(rotation=90);

# %% [markdown]
# ## Time Varying Composition of Data

# %% [markdown]
# ### Stacked Area Plots

# %%
 df_ = df[['mh', 'date', 'status']]

# %%
df_.head()
# Out:
#    mh       date     status
# 0  14  14-Mar-20  Confirmed
# 1   0  14-Mar-20  Recovered
# 2   0  14-Mar-20   Deceased
# 3  18  15-Mar-20  Confirmed
# 4   0  15-Mar-20  Recovered

# %%
df_['mh'] = pd.to_numeric(df_['mh'])
df_['date'] = pd.to_datetime(df_['date'])
# Out:
# /Users/partha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/partha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_.head()
# Out:
#    mh       date     status
# 0  14 2020-03-14  Confirmed
# 1   0 2020-03-14  Recovered
# 2   0 2020-03-14   Deceased
# 3  18 2020-03-15  Confirmed
# 4   0 2020-03-15  Recovered

# %%
df_ = pd.pivot_table(data=df_, values='mh', columns ='status', index='date')

# %%
df_
# Out:
# status      Confirmed  Deceased  Recovered
# date
# 2020-03-14         14         0          0
# 2020-03-15         18         0          0
# 2020-03-16          6         0          0
# 2020-03-17          3         1          0
# 2020-03-18          3         0          0
# ...               ...       ...        ...
# 2020-07-14       6741       213       4500
# 2020-07-15       7975       233       3606
# 2020-07-16       8641       266       5527
# 2020-07-17       8308       258       2217
# 2020-07-18       8348       144       5306
#
# [127 rows x 3 columns]

# %%
df_.plot.area()

# %%
plt.stackplot(df_.index,df_.Confirmed, df_.Recovered,df_.Deceased);

# %%
fig = plt.gcf()
fig.set_size_inches(30, 6);
plt.stackplot(df_.index,df_.Confirmed, df_.Recovered,df_.Deceased,
              labels= ['Confirmed','Recovered','Deceased'],
             colors=['green','orange','red']);
plt.legend();

# %%
fig = plt.gcf()
fig.set_size_inches(30, 6);
plt.stackplot(df_.index,df_.Confirmed/df_.sum(axis=1), 
              df_.Recovered/df_.sum(axis=1),
              df_.Deceased/df_.sum(axis=1),
              labels= ['Confirmed','Recovered','Deceased'],
             colors=['green','orange','red']);
plt.legend();

# %%
def stacked_area_state(state):
    df_ = df[[state, 'date', 'status']]
    df_[state] = pd.to_numeric(df_[state])
    df_['date'] = pd.to_datetime(df_['date'])
    df_ = pd.pivot_table(data=df_, values=state, columns ='status', index='date')
    fig = plt.gcf()
    fig.set_size_inches(30, 6);
    plt.stackplot(df_.index,df_.Confirmed/df_.sum(axis=1), 
                  df_.Recovered/df_.sum(axis=1),
                  df_.Deceased/df_.sum(axis=1),
                  labels= ['Confirmed','Recovered','Deceased'],
                  colors=['green','orange','red']);
    plt.legend();

# %%
stacked_area_state('tn')
# Out:
# /Users/partha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/partha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
stacked_area_state('dl')
# Out:
# /Users/partha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/partha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# # Plotting Relationships between data #

# %% [markdown]
# ## Scatter Plot

# %%
t = sns.load_dataset('tips')

# %%
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill', y = 'tip', data=t);

# %%
t['tip_fraction'] = t['tip'] / t['total_bill']

# %%
sns.scatterplot(x='total_bill', y = 'tip_fraction', data=t);

# %%
sns.scatterplot(x='total_bill', y = 'tip', data=t, hue='time');

# %%
sns.scatterplot(x='total_bill', y = 'tip', data=t, hue='sex');

# %%
sns.scatterplot(x='total_bill', y = 'tip', data=t, hue='smoker');

# %%
sns.scatterplot(x='total_bill', y = 'tip', data=t, hue='day');

# %%
sns.scatterplot(x='total_bill', y = 'tip', data=t, hue='size');

# %%
sns.scatterplot(x='total_bill', y = 'tip', data=t, hue='size', style='sex');

# %%
sns.scatterplot(x='total_bill', y = 'tip', data=t, hue='time', style='sex',size='size');

# %%
sns.scatterplot(x='total_bill', y = 'tip', data=t, hue='time', style='sex',size='size')
plt.legend(bbox_to_anchor=(1.05,1.0));

# %%
sns.regplot(x='total_bill', y = 'tip', data=t);
#plt.legend(bbox_to_anchor=(1.05,1.0));

# %%
sns.regplot(x='total_bill', y = 'tip_fraction', data=t);

# %%
sns.regplot(x='total_bill', y = 'tip_fraction', data=t,marker='+');

# %%
d = sns.load_dataset('diamonds')

# %%
d.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.regplot('x', 'price', data=d);

# %%
sns.scatterplotplot('x', 'price', data=d);

# %%
sns.scatterplot('x', 'price', data=d.sample(1000));

# %%
sns.regplot('x', 'price', data=d.sample(1000));

# %%
sns.regplot('x', 'price', data=d.sample(1000), order=2);

# %% [markdown]
# ## Bar Plot

# %%
sns.barplot('cut', 'price', data=d.sample(1000));

# %%
sns.barplot('day', 'tip', data=t);

# %%
sns.barplot('day', 'tip_fraction', data=t);

# %%
sns.barplot('day', 'tip', data=t,estimator=np.median);

# %%
def my_estimate(v):
    return np.quantile(v, 0.25)

# %%
sns.barplot('day', 'tip', data=t,estimator=my_estimate);

# %%
sns.barplot('day', 'tip', data=t,hue = 'sex' , estimator=np.median);

# %%
sns.barplot('day', 'tip', data=t,hue = 'smoker' , estimator=np.median);

# %%
sns.barplot('day', 'tip', data=t,hue = 'time' , estimator=np.median);

# %% [markdown]
# ## Continuous Vs Discrete Plot

# %%
#scatter plot - Both x and y axis are continuous
#bar plot y is continuous and x is discrete

# %%
sns.scatterplot('x', 'price', data = d.sample(1000));

# %%
sns.barplot('x', 'price', data = d.sample(1000));

# %%
# NOT AN INFORMATIVE PLOT

# %%
d['x_q'] = pd.cut(d['x'], bins=15)

# %%
d.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#               x_q
# 0   (3.58, 4.296]
# 1   (3.58, 4.296]
# 2   (3.58, 4.296]
# 3   (3.58, 4.296]
# 4  (4.296, 5.012]

# %%
sns.barplot('x_q', 'price', data = d.sample(1000));

# %%
d['x_q'] = pd.cut(d['x'], bins=15,labels=False)

# %%
d.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  x_q
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43    5
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31    5
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31    5
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63    5
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75    6

# %%
sns.barplot('x_q', 'price', data = d.sample(1000));

# %% [markdown]
# ## Line Plot

# %%
f = sns.load_dataset('fmri')

# %%
f.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot('timepoint', 'signal', data=f);

# %%
sns.lineplot('timepoint', 'signal', hue='region', data=f);

# %%
sns.lineplot('timepoint', 'signal', hue='event', data=f);

# %%
sns.lineplot('timepoint', 'signal', hue='event', style='region', data=f);

# %%
sns.lineplot('timepoint', 'signal', marker=True, data=f);

# %%
# how to change the color of marker

# %%
sns.lineplot('timepoint', 'signal', marker=True, estimator= np.median,data=f);

# %%
sns.lineplot('timepoint', 'signal', data=f, units = 'subject', estimator=None);

# %%
f_ = f[(f.region == 'parietal') & (f.event == 'cue')]

# %%
f_.head()
# Out:
#     subject  timepoint event    region    signal
# 532      s3          4   cue  parietal  0.058219
# 533      s6          5   cue  parietal  0.038145
# 534      s7          5   cue  parietal -0.008158
# 535      s8          5   cue  parietal  0.047136
# 536      s9          5   cue  parietal  0.055847

# %%
sns.lineplot('timepoint', 'signal', data=f_, units = 'subject', estimator=None);

# %%
with open('data.json') as f:
    data = json.load(f)
data = data['states_daily']
df = pd.json_normalize(data)
df['date'] = pd.to_datetime(df['date'])
df.drop('tt', axis=1, inplace=True)
df.set_index('date', inplace= True)
df = df[df['status'] == 'Confirmed']
df.drop('status', inplace = True,axis=1)
df = df.apply(pd.to_numeric)
df = df.rolling(7).mean()
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#         date  an  ap  ar  as  br  ch  ct  dd  dl  ...  py  rj  sk  tg  tn  tr  \
# 0 2020-03-14 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN
# 1 2020-03-15 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN
# 2 2020-03-16 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN
# 3 2020-03-17 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN
# 4 2020-03-18 NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN
#
#    un  up  ut  wb
# 0 NaN NaN NaN NaN
# 1 NaN NaN NaN NaN
# 2 NaN NaN NaN NaN
# 3 NaN NaN NaN NaN
# 4 NaN NaN NaN NaN
#
# [5 rows x 39 columns]

# %%
df_ = pd.melt(df, id_vars= "date", 
              value_vars= list(df.columns).remove("date"),
              var_name = "state", value_name = "confirmed")

# %%
df_.head()
# what is the different pivort
# Out:
#         date state  confirmed
# 0 2020-03-14    an        NaN
# 1 2020-03-15    an        NaN
# 2 2020-03-16    an        NaN
# 3 2020-03-17    an        NaN
# 4 2020-03-18    an        NaN

# %%
sns.lineplot('date', 'confirmed',data = df_);

# %%
states =['mh', 'tn','dl','wb', 'gj']

# %%
df_ = df_[df_.state.isin(states)]

# %%
df_.head()
# Out:
#            date state  confirmed
# 1016 2020-03-14    dl        NaN
# 1017 2020-03-15    dl        NaN
# 1018 2020-03-16    dl        NaN
# 1019 2020-03-17    dl        NaN
# 1020 2020-03-18    dl        NaN

# %%
sns.lineplot('date', 'confirmed',hue='state', data = df_);

# %%
sns.lineplot('date', 'confirmed',hue='state', palette= 'Reds',data = df_);

# %%
fig = plt.gcf()
fig.set_size_inches(15,6)
sns.lineplot('date', 'confirmed',hue='state', palette= 'Reds',data = df_);

# %%
fig = plt.gcf()
fig.set_size_inches(15,6)
sns.lineplot('date', 'confirmed',hue='state', palette= 'Reds',
             data = df_, hue_order=['ka','wb','gj','dl','tn','mh']);

# %% [markdown]
# ### Heat Map

# %%
# discrete variables on both axis
x = np.random.rand(10,10)

# %%
sns.heatmap(x);

# %%
f1 = sns.load_dataset('flights')

# %%
f1.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
f1_ = f1.pivot(index='year', columns='month', values='passengers')

# %%
f1_.head()
# Out:
# month  January  February  March  April  May  June  July  August  September  \
# year
# 1949       112       118    132    129  121   135   148     148        136
# 1950       115       126    141    135  125   149   170     170        158
# 1951       145       150    178    163  172   178   199     199        184
# 1952       171       180    193    181  183   218   230     242        209
# 1953       196       196    236    235  229   243   264     272        237
#
# month  October  November  December
# year
# 1949       119       104       118
# 1950       133       114       140
# 1951       162       146       166
# 1952       191       172       194
# 1953       211       180       201

# %%
sns.heatmap(f1_)

# %%
sns.heatmap(f1_.T);

# %%
sns.heatmap(f1_.T, annot=True,fmt='d');

# %%
fig = plt.gcf()
fig.set_size_inches(15,6);
sns.heatmap(f1_.T, annot=True,fmt='d');

# %%
fig = plt.gcf()
fig.set_size_inches(15,6);
sns.heatmap(f1_.T, annot=True,fmt='d',cmap='YlGnBu');

# %%
fig = plt.gcf()
fig.set_size_inches(15,6);
sns.heatmap(f1_.T, annot=True,fmt='d',cmap=sns.diverging_palette(250,10,n=10));

# %%
fig = plt.gcf()
fig.set_size_inches(15,6);
sns.heatmap(f1_.T, annot=True,fmt='d',cmap=sns.diverging_palette(50,200,n=10));

# %%
fig = plt.gcf()
fig.set_size_inches(15,6);
sns.heatmap(f1_.T, annot=True,fmt='d',cmap=sns.diverging_palette(50,200,n=10),
           center=f1_.loc[1957,'July']);

# %%
fig = plt.gcf()
fig.set_size_inches(15,6);
sns.heatmap(f1_.T, annot=True,fmt='d',cmap=sns.diverging_palette(250,10,n=10),
           center=f1_.loc[1957,'July']);
